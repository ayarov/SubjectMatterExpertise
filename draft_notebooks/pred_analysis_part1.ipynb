# %%
# %autosave 10000
import pandas as pd
import numpy as np
from IPython.display import display, HTML
# Out:
# Autosaving every 10000 seconds

# %%
test_data = pd.read_pickle(r'data/test_data_385_articles.bz2', compression='bz2')
test_data.shape
# Out:
# (41856, 59)

# %%
print('total pages: {}'.format(len(test_data['page_id'].unique())))
print('total pairs: {}'.format(len(test_data)))
print('total users: {}'.format(len(test_data['user'].unique())))
# Out:
# total pages: 385
# total pairs: 41856
# total users: 35449

# %%
data1 = []
cols1 = ['Category', 'Pairs']
categories = test_data['category'].unique()
for cat in categories:
    if pd.isnull(cat):
        continue
    n_pairs = len(test_data[test_data['category'] == cat])
    data1.append([cat, n_pairs])

df1 = pd.DataFrame(data=data1, columns=cols1)
df1.to_csv(r'data/category_pairs_385.csv', index=False)
df1.style.bar(align='left', color=['#d65f5f', '#5fba7d'])
# df.style.highlight_max(axis=0)
# display(df)
# display(HTML(df.to_html()))
# Out:
# <style  type="text/css" >
#     #T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 25.2%, transparent 0%);
#         }    #T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 10.3%, transparent 0%);
#         }    #T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 33.1%, transparent 0%);
#         }    #T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 9.7%, transparent 0%);
#         }    #T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 59.6%, transparent 0%);
#         }    #T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 28.9%, transparent 0%);
#         }    #T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 22.6%, transparent 0%);
#         }    #T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 52.1%, transparent 0%);
#         }    #T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 53.1%, transparent 0%);
#         }    #T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 56.4%, transparent 0%);
#         }    #T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 10.8%, transparent 0%);
#         }    #T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 73.7%, transparent 0%);
#         }    #T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 42.3%, transparent 0%);
#         }    #T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 39.9%, transparent 0%);
#         }    #T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 67.9%, transparent 0%);
#         }    #T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 96.7%, transparent 0%);
#         }    #T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 61.5%, transparent 0%);
#         }    #T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 51.9%, transparent 0%);
#         }    #T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row18_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 43.9%, transparent 0%);
#         }    #T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row19_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 57.6%, transparent 0%);
#         }    #T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row20_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 13.2%, transparent 0%);
#         }    #T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row21_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 0%);
#         }    #T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row22_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 53.8%, transparent 0%);
#         }    #T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row23_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 18.6%, transparent 0%);
#         }    #T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row24_col1 {
#             width:  10em;
#              height:  80%;
#         }</style>
# <table id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Category</th>
#         <th class="col_heading level0 col1" >Pairs</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row0_col0" class="data row0 col0" >Agriculture</td>
#         <td id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row0_col1" class="data row0 col1" >1160</td>
#     </tr>    <tr>
#         <th id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row1_col0" class="data row1 col0" >History</td>
#         <td id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row1_col1" class="data row1 col1" >736</td>
#     </tr>    <tr>
#         <th id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row2_col0" class="data row2 col0" >Humanities</td>
#         <td id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row2_col1" class="data row2 col1" >1384</td>
#     </tr>    <tr>
#         <th id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row3_col0" class="data row3 col0" >Sports</td>
#         <td id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row3_col1" class="data row3 col1" >719</td>
#     </tr>    <tr>
#         <th id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row4_col0" class="data row4 col0" >Education</td>
#         <td id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row4_col1" class="data row4 col1" >2137</td>
#     </tr>    <tr>
#         <th id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row5_col0" class="data row5 col0" >Chronology</td>
#         <td id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row5_col1" class="data row5 col1" >1265</td>
#     </tr>    <tr>
#         <th id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row6_col0" class="data row6 col0" >Nature</td>
#         <td id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row6_col1" class="data row6 col1" >1084</td>
#     </tr>    <tr>
#         <th id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0level0_row7" class="row_heading level0 row7" >7</th>
#         <td id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row7_col0" class="data row7 col0" >Mathematics</td>
#         <td id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row7_col1" class="data row7 col1" >1923</td>
#     </tr>    <tr>
#         <th id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0level0_row8" class="row_heading level0 row8" >8</th>
#         <td id="T_f7e44b66_6c1b_11e8_acc1_0686a17035b0row8_col0" class="data row8 col0" >Business</td>

# %%
data2 = []
cols2 = ['Category', 'Pages']
categories = test_data['category'].unique()
for cat in categories:
#     if pd.isnull(cat):
#         continue
    n_pages = len(test_data[test_data['category'] == cat]['page_id'].unique())
    data2.append([cat, n_pages])

df2 = pd.DataFrame(data=data2, columns=cols2)
df2.to_csv(r'data/category_pages_385.csv', index=False)
df2.style.bar(align='left', color=['#d65f5f', '#5fba7d'], width=100)

# print(np.sum(df2.Pages))
# Out:
# <style  type="text/css" >
#     #T_02e4916a_6c1c_11e8_acc1_0686a17035b0row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 63.6%, transparent 0%);
#         }    #T_02e4916a_6c1c_11e8_acc1_0686a17035b0row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 63.6%, transparent 0%);
#         }    #T_02e4916a_6c1c_11e8_acc1_0686a17035b0row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 63.6%, transparent 0%);
#         }    #T_02e4916a_6c1c_11e8_acc1_0686a17035b0row3_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_02e4916a_6c1c_11e8_acc1_0686a17035b0row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 68.2%, transparent 0%);
#         }    #T_02e4916a_6c1c_11e8_acc1_0686a17035b0row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 86.4%, transparent 0%);
#         }    #T_02e4916a_6c1c_11e8_acc1_0686a17035b0row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 68.2%, transparent 0%);
#         }    #T_02e4916a_6c1c_11e8_acc1_0686a17035b0row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 18.2%, transparent 0%);
#         }    #T_02e4916a_6c1c_11e8_acc1_0686a17035b0row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 72.7%, transparent 0%);
#         }    #T_02e4916a_6c1c_11e8_acc1_0686a17035b0row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 54.5%, transparent 0%);
#         }    #T_02e4916a_6c1c_11e8_acc1_0686a17035b0row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 72.7%, transparent 0%);
#         }    #T_02e4916a_6c1c_11e8_acc1_0686a17035b0row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 50.0%, transparent 0%);
#         }    #T_02e4916a_6c1c_11e8_acc1_0686a17035b0row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 50.0%, transparent 0%);
#         }    #T_02e4916a_6c1c_11e8_acc1_0686a17035b0row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 86.4%, transparent 0%);
#         }    #T_02e4916a_6c1c_11e8_acc1_0686a17035b0row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 95.5%, transparent 0%);
#         }    #T_02e4916a_6c1c_11e8_acc1_0686a17035b0row15_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_02e4916a_6c1c_11e8_acc1_0686a17035b0row16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 63.6%, transparent 0%);
#         }    #T_02e4916a_6c1c_11e8_acc1_0686a17035b0row17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 68.2%, transparent 0%);
#         }    #T_02e4916a_6c1c_11e8_acc1_0686a17035b0row18_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 68.2%, transparent 0%);
#         }    #T_02e4916a_6c1c_11e8_acc1_0686a17035b0row19_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 0%);
#         }    #T_02e4916a_6c1c_11e8_acc1_0686a17035b0row20_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 4.5%, transparent 0%);
#         }    #T_02e4916a_6c1c_11e8_acc1_0686a17035b0row21_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 68.2%, transparent 0%);
#         }    #T_02e4916a_6c1c_11e8_acc1_0686a17035b0row22_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 4.5%, transparent 0%);
#         }    #T_02e4916a_6c1c_11e8_acc1_0686a17035b0row23_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 50.0%, transparent 0%);
#         }    #T_02e4916a_6c1c_11e8_acc1_0686a17035b0row24_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 68.2%, transparent 0%);
#         }</style>
# <table id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Category</th>
#         <th class="col_heading level0 col1" >Pages</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0row0_col0" class="data row0 col0" >Agriculture</td>
#         <td id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0row0_col1" class="data row0 col1" >17</td>
#     </tr>    <tr>
#         <th id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0row1_col0" class="data row1 col0" >History</td>
#         <td id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0row1_col1" class="data row1 col1" >17</td>
#     </tr>    <tr>
#         <th id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0row2_col0" class="data row2 col0" >Humanities</td>
#         <td id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0row2_col1" class="data row2 col1" >17</td>
#     </tr>    <tr>
#         <th id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0row3_col0" class="data row3 col0" >Sports</td>
#         <td id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0row3_col1" class="data row3 col1" >3</td>
#     </tr>    <tr>
#         <th id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0row4_col0" class="data row4 col0" >Education</td>
#         <td id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0row4_col1" class="data row4 col1" >18</td>
#     </tr>    <tr>
#         <th id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0row5_col0" class="data row5 col0" >Chronology</td>
#         <td id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0row5_col1" class="data row5 col1" >22</td>
#     </tr>    <tr>
#         <th id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0row6_col0" class="data row6 col0" >Nature</td>
#         <td id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0row6_col1" class="data row6 col1" >18</td>
#     </tr>    <tr>
#         <th id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0level0_row7" class="row_heading level0 row7" >7</th>
#         <td id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0row7_col0" class="data row7 col0" >Mathematics</td>
#         <td id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0row7_col1" class="data row7 col1" >7</td>
#     </tr>    <tr>
#         <th id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0level0_row8" class="row_heading level0 row8" >8</th>
#         <td id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0row8_col0" class="data row8 col0" >Business</td>
#         <td id="T_02e4916a_6c1c_11e8_acc1_0686a17035b0row8_col1" class="data row8 col1" >19</t

# %%
# list(test_data.columns)

# %%
article_category_df = pd.read_excel(r'd:/temp/test_data.xlsx')
article_scope_df = pd.read_excel(r'd:/temp/activity_scope.xlsx')
article_users_df = pd.read_excel(r'd:/temp/test_users_data.xlsx')

# %%
# article_category_df.head()

# %%
# tmp_df = article_users_df.merge(article_scope_df, how='left', on='article_id')
# tmp_df[tmp_df.registered].head(50)

# %%
df = article_category_df.merge(article_scope_df, how='inner', on='article_id')
df = article_users_df.merge(df, how='left', on='article_id')

# %%
rows = []
grouped = df.groupby('article_id')
for article_id, group in grouped:
    category = group['category'].iloc[0]
    article = group['article'].iloc[0]    
    maturity = group['activity_scope'].iloc[0]
    total_registered = len(group[group.registered])
    total_unregistered = len(group[~group.registered])
    total_unique = len(group['user'].unique())
    
    sorted_group = group.sort_values(by='expert', ascending=False)
    
    top_10 = sorted_group.head(10)
    top_10_registered = len(top_10[sorted_group.registered==True])
    top_10_unregistered = len(top_10[sorted_group.registered==False])
    
    top5_registered = sorted_group[sorted_group.registered].head(5)
    top5_80_registered = sorted_group[(sorted_group.registered) & (sorted_group.expert > 0.8)].head(5)
    
    top5_expert = len(top5_registered[top5_registered['evaluation']=='expert'])
    top5_no_page = len(top5_registered[top5_registered['evaluation']=='no_page'])
    top5_not_expert = len(top5_registered[top5_registered['evaluation']=='not_expert'])
    top5_practitioner = len(top5_registered[top5_registered['evaluation']=='practiotioner'])
    top5_scholar = len(top5_registered[top5_registered['evaluation']=='scholar'])
    top5_unknown = len(top5_registered[top5_registered['evaluation']=='unknown'])
    top5_wikipedian = len(top5_registered[top5_registered['evaluation']=='wikipedian'])
    top5_nan = len(top5_registered[top5_registered['evaluation'].isnull()])
    
    top5_80_expert = len(top5_80_registered[top5_80_registered['evaluation']=='expert'])
    top5_80_no_page = len(top5_80_registered[top5_80_registered['evaluation']=='no_page'])
    top5_80_not_expert = len(top5_80_registered[top5_80_registered['evaluation']=='not_expert'])
    top5_80_practitioner = len(top5_80_registered[top5_80_registered['evaluation']=='practiotioner'])
    top5_80_scholar = len(top5_80_registered[top5_80_registered['evaluation']=='scholar'])
    top5_80_unknown = len(top5_80_registered[top5_80_registered['evaluation']=='unknown'])
    top5_80_wikipedian = len(top5_80_registered[top5_80_registered['evaluation']=='wikipedian'])
    top5_80_nan = len(top5_80_registered[top5_80_registered['evaluation'].isnull()])
        
    rows.append([category, 
                 article, 
                 article_id, 
                 maturity, 
                 total_unique, 
                 total_registered, 
                 total_unregistered, 
                 top_10_registered, 
                 top_10_unregistered,
                 top5_expert,
                 top5_no_page,
                 top5_not_expert,
                 top5_practitioner,
                 top5_scholar,
                 top5_unknown,
                 top5_wikipedian,
                 top5_nan,
                 top5_80_expert,
                 top5_80_no_page,
                 top5_80_not_expert,
                 top5_80_practitioner,
                 top5_80_scholar,
                 top5_80_unknown,
                 top5_80_wikipedian,
                 top5_80_nan])

new_df = pd.DataFrame(rows, columns=['category', 
                                     'article',
                                     'article_id', 
                                     'maturity', 
                                     '#distinct_users',
                                     '#registered_users',
                                     '#unregistered_users',
                                     '#top10_registered_users',
                                     '#top10_unregistered_users',
                                     'top5_expert',
                                     'top5_no_page',
                                     'top5_not_expert',
                                     'top5_practitioner',
                                     'top5_scholar',
                                     'top5_unknown',
                                     'top5_wikipedian',
                                     'top5_nan',
                                     'top5_80_expert',
                                     'top5_80_no_page',
                                     'top5_80_not_expert',
                                     'top5_80_practitioner',
                                     'top5_80_scholar',
                                     'top5_80_unknown',
                                     'top5_80_wikipedian',
                                     'top5_80_nan'])
new_df = new_df.sort_values(by='category', ascending=True)
new_df.head()

# %% [markdown]
# ### Add activity scope for each article

# %%
new_df = new_df.sort_values(by='category', ascending=True)
new_df.to_excel(r'd:/temp/test_analysis.xlsx', index=False)

# %%
def average_by_column(column):
    avg_rows = []
    avg_cols = [col for col in new_df.columns if col not in ['category', 'article', 'article_id', 'maturity']]
    groups_by_column = new_df.groupby(column)
    for group_column, group in groups_by_column:
        avg_row = [group_column]
        for col in avg_cols:
            avg_row.append(np.round(np.average(group[col]), 2))
        avg_rows.append(avg_row)
    return pd.DataFrame(avg_rows, columns=[column] + avg_cols)

# %%
by_category_df = average_by_column('category')
by_category_df.to_excel(r'd:/temp/avg_by_category.xlsx', index=False)

# %%
by_maturity_df = average_by_column('maturity')
by_maturity_df.to_excel(r'd:/temp/avg_by_maturity.xlsx', index=False)
